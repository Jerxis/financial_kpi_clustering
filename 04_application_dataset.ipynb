# %% [markdown]
# # Objective of This Notebook
# This notebook constructs an application-ready dataset containing company metadata, original financial values, calculated KPIs, KPI availability indicators and supporting fields required for peer benchmarking and value-at-stake analysis. Scenario-specific imputation, winsorisation, scaling and clustering are intentionally excluded and will be performed dynamically within the analytical application layer.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent
INTERIM_DIR = PROJECT_ROOT / "data" / "interim"
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

input_path = INTERIM_DIR / "your_latest_clean_dataset.parquet"
df = pd.read_parquet(input_path)
